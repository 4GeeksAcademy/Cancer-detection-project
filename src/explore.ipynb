# %% [markdown]
# # Explore here

# %%
import pandas as pd

# %%
data_prostate = pd.read_csv("/workspaces/Cancer-detection-project/data/raw/prostate c data.csv", sep=";")
data_prostate
# Out:
#         Date_Dx       region  Education_status  maritalstatus  ageatdiagnoses  \
# 0    11/20/2016        SNNPR                 4              5              64
# 1     4/09/2015  ADDIS ABABA                 2              1              58
# 2     6/06/2016  ADDIS ABABA                 2              1              65
# 3     9/10/2016  ADDIS ABABA                 1              1              52
# 4     4/20/2014  ADDIS ABABA                 1              1              80
# ..          ...          ...               ...            ...             ...
# 132  10/17/2012  ADDIS ABABA                 3              1              76
# 133   6/15/2014      OROMIYA                 4              1              79
# 134   8/29/2014      OROMIYA                 1              1              53
# 135   3/18/2016  ADDIS ABABA                 2              1              65
# 136   1/26/2016       AMHARA                 1              1              55
#
# ...

# %%
data_prostate.columns
# Out:
# Index(['Date_Dx', 'region', 'Education_status', 'maritalstatus',
#        'ageatdiagnoses', 'Tobacco', 'Alcohol', 'Khat', 'Family_history',
#        'HIVinfectionstatus', 'DM', 'HTN', 'tumormarkertest', 'US', 'Biopsy',
#        'FU_last', 'enddate', 'Status_patient', 'Date_death', 'PSA_level',
#        'Gleason_score', 'Hist_grade', 'Hist_type', 'TNM_stage',
#        'Tstageofcancer', 'Nstageofcancer', 'Mstageofcancer', 'Dist_metastasis',
#        'Bone_metastasis', 'LN_metastasis', 'Other_metastasis', 'Time_to_death',
#        'Orchioectomy', 'Radiotherapy', 'boneturgotedtreatment', 'Chemotherapy',
#        'statusatlastcontact', 'prostatectomy', 'ADT', 'ponly', 'honly',
#        'ronly'],
#       dtype='object')

# %%
data_esophageal = pd.read_csv("/workspaces/Cancer-detection-project/data/raw/esophageal.csv", sep=";")
data_esophageal
# Out:
#          DATEDX  Age  Education  Sex       Region  Mstatus  Alcohol  Khat  \
# 0    12/14/2010   66          3    1       OROMIA        2        2     2
# 1     5/15/2010   66          3    2  ADDIS ABABA        2        2     1
# 2     2/02/2010   62          1    2  ADDIS ABABA        2        1     1
# 3     3/30/2010   62          1    2       OROMIA        2        1     2
# 4     4/15/2010   45          4    1       OROMIA        2        2     2
# ..          ...  ...        ...  ...          ...      ...      ...   ...
# 344   2/06/2016   55          3    2       OROMIA        2        2     1
# 345   2/09/2016   45          2    1        SNNPR        2        2     2
# 346   2/10/2016   67          2    2  ADDIS ABABA        2        2     1
# 347   3/21/2016   32          2    1       OROMIA        2        2     2
# 348   8/01/2016   58          2    2       AMHARA        2        1     1
#
#      Tobacco Comorbidity  ...  Chemotherapy  Chemo_type  Chemo_cycle  \
# ...

# %%
data_colorectal = pd.read_csv("/workspaces/Cancer-detection-project/data/raw/colorectal.csv", sep=";")
data_colorectal
# Out:
#         Date_Dx  Age  Sex       Region  MStatus  Edu_status  Family_history  \
# 0    10/09/2014   72    0  Addis Ababa        2           1               0
# 1    11/13/2015   50    1  Addis Ababa        1           1               0
# 2     9/06/2015   33    1  Addis Ababa        1           1               0
# 3     4/01/2012   65    0  Addis Ababa        2           1               0
# 4     6/11/2012   55    1  Addis Ababa        2           2               0
# ..          ...  ...  ...          ...      ...         ...             ...
# 156   9/03/2015   63    0       Amhara        2           3               0
# 157   2/16/2016   32    1  Addis Ababa        1           3               0
# 158   4/25/2013   58    0  Addis Ababa        2           4               0
# 159   9/02/2015   59    1       Oromia        2           1               0
# 160   1/30/2012   60    0        SNNPR        2           1               0
#
# ...

# %%
data_prostate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date_Dx                137 non-null    object
#  1   region                 137 non-null    object
#  2   Education_status       137 non-null    int64
#  3   maritalstatus          137 non-null    int64
#  4   ageatdiagnoses         137 non-null    int64
#  5   Tobacco                137 non-null    int64
#  6   Alcohol                137 non-null    object
#  7   Khat                   137 non-null    object
#  8   Family_history         137 non-null    int64
#  9   HIVinfectionstatus     137 non-null    int64
#  10  DM                     137 non-null    int64
#  11  HTN                    137 non-null    int64
#  12  tumormarkertest        137 non-null    int64
#  13  US                     137 non-null    int64
#  14  Biopsy                 137 non-null    int64
# ...
